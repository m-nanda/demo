# %% [markdown]
# # Library Set-Up

# %%
import os
import background_check as bc
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Response Summary of Class 1

# %%
CLASS_ID = os.getenv("CLASS_ID")
SHEET_ID = os.getenv("SHEET_ID")
url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv'
df = bc.read_response(url, CLASS_ID)
display(df.sample(5))
bc.viz_summary_1(df)
df_txt = bc.preprocess_text_data(df)
bc.viz_summary_2(df_txt, -1)
bc.viz_summary_2(df_txt, -2)
# Out:
#              Timestamp Do you familiar with PyCharm?  \
# 1   6/30/2023 14:30:37                            No
# 3   6/30/2023 14:39:55                            No
# 16   7/4/2023 13:31:13                            No
# 8    7/1/2023 20:27:19                           Yes
# 13   7/3/2023 13:18:33                            No
#
#    Which one the hardest case of machine learning for you?  \
# 1                                          Text / NLP
# 3                                          Timeseries
# 16                                         Regression
# 8                                          Text / NLP
# 13                                         Regression
#
#     How interested are you in taking the  TensorFlow Dev. Certification?  \
# 1                                                   5
# 3                                                   5
# 16                                                  5
# 8                                                   4
# ...

# %% [markdown]
# # Response Summary of Class 2

# %%
CLASS_ID = os.getenv("CLASS_ID_")
df = bc.read_response(url, CLASS_ID)
display(df.sample(5))
bc.viz_summary_1(df)
df_txt = bc.preprocess_text_data(df)
bc.viz_summary_2(df_txt, -1)
bc.viz_summary_2(df_txt, -2)
# Out:
#             Timestamp Do you familiar with PyCharm?  \
# 16   7/4/2023 5:21:31                            No
# 23  7/4/2023 15:07:23                            No
# 6   7/1/2023 18:01:22                            No
# 12  7/2/2023 20:31:07                           Yes
# 24  7/4/2023 15:48:32                           Yes
#
#    Which one the hardest case of machine learning for you?  \
# 16                                         Regression
# 23                                         Timeseries
# 6                                          Timeseries
# 12                                         Timeseries
# 24                                         Text / NLP
#
#     How interested are you in taking the  TensorFlow Dev. Certification?  \
# 16                                                  3
# 23                                                  4
# 6                                                   3
# 12                                                  5
# ...
